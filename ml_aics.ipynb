# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("logdata.csv")
df.drop(['Unnamed: 0'],axis=1)
# Out:
#      hours  mins  seconds  month  day  year  log
# 0        8     9       47     11    6  2022    1
# 1        8    20       29     11    7  2022    1
# 2        8    33       29     11    8  2022    1
# 3        8    16       43     11    9  2022    1
# 4        8    36       16     11   10  2022    1
# ..     ...   ...      ...    ...  ...   ...  ...
# 195     18    44       53     12   26  2022    0
# 196     18    16       46     12   27  2022    0
# 197     18    30       38     12   28  2022    0
# 198     18    55       31     12   29  2022    0
# 199     18     2       34     12   30  2022    0
#
# [200 rows x 7 columns]

# %%
X = df.drop(['month','day','year','log','Unnamed: 0'], axis=1)
Y = df.log

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3)

# %%
knn = KNeighborsClassifier(n_neighbors = 10)
knn = knn.fit(X,Y)
y_pred = knn.predict(X_test)

# %%
knn.score(X_test,Y_test)
# Out:
# 0.6833333333333333

# %%
from sklearn.svm import SVC
svmclassifier = SVC()
svmclassifier = svmclassifier.fit(X_train,Y_train)
y_pred_svm = svmclassifier.predict(X_test)

# %%
svmclassifier.score(X_test,Y_test)
# Out:
# 0.6166666666666667

# %%
from sklearn.naive_bayes import BernoulliNB
bernoulli = BernoulliNB()
bernoulli.fit(X_train,Y_train)
Y_pred_nb = bernoulli.predict(X_test)

# %%
bernoulli.score(X_test,Y_test)
# Out:
# 0.48333333333333334

# %%
from sklearn.tree import DecisionTreeClassifier
dtreef = DecisionTreeClassifier(max_depth=6,ccp_alpha=0.002)
dtreef.fit(X_train,Y_train)
Y_preddt = dtreef.predict(X_test)

# %%
dtreef.score(X_test,Y_test)
# Out:
# 1.0

# %%
import joblib
import pickle

# %%
joblib.dump(knn,'aics_KN.pkl')
# Out:
# ['aics_KN.pkl']

# %%
model = joblib.load('aics_KN.pkl')
model.predict(X_test[0:1])
# Out:
# array([1], dtype=int64)

# %%
X_test
# Out:
#      hours  mins  seconds
# 141     14    51        8
# 12       8    19       57
# 111     14    29        8
# 55      12    31       44
# 66      12    12       45
# 144     14    57       24
# 169     18    35       21
# 36       8    47        6
# 152     18    34       12
# 123     14    34        5
# 29       8    56       32
# 129     14     1       45
# 193     18    48       25
# 70      12    54       15
# 159     18    35       14
# 160     18    24       18
# 163     18    13       34
# 26       8    16       13
# 130     14    21       39
# 54      12    40       45
# 38       8    11       12
# 116     14     2       47
# 73      12    21        7
# 21       8    30       33
# 156     18    46        0
# 89      12    58       30
# 31       8    30       26
# 5        8    13       55
# 43       8    58       51
# 143     14    34       44
# 148     14    29       58
# 124     14    34        7
# 17       8    15       10
# 131     14     6       45
# ...
